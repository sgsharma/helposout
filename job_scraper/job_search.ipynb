# %% [markdown]
# ## Scraping to get job info for OS orgs
#
# **TL;DR:**
# If you want to keep this away from using paid tools etc. I'd begin with users simply posting the positions via a form or importing from a structured CSV/gSheet/Excel sheet etc.
#
# **Attempted dataflow:**
# - Read from gSheet listing OS orgs of interest
# - Attempt to find jobs/careers pages on their websites
#     - Parse resulting html etc.
# - Attempt to find jobs/careers from search engine results for the orgs

# %%
from helper import *

# %%
# read from gSheet
scope = ['https://spreadsheets.google.com/feeds',
            'https://www.googleapis.com/auth/drive']

orgs = read_gsheet(scope, 'os_orgs')['org']

# %% [markdown]
# ### First approach: Look at what the careers/jobs pages look like for some of these

# %%
job_pages_df = pd.DataFrame([google(x + ' careers')[0] for x in orgs[:5]])

# %%
job_pages_df
# Out:
#                                text  \
# 0                 Jobs - Hypothesis
# 1                    Careers - PLOS
# 2  Opportunities - Creative Commons
# 3              Dat Project · GitHub
# 4             Careers - ContentMine
#
#                                                  url
# 0                      https://web.hypothes.is/jobs/
# 1                          https://plos.org/careers/
# 2  https://creativecommons.org/about/team/opportu...
# 3                      https://github.com/datproject
# 4       http://contentmine.org/get-in-touch/careers/

# %% [markdown]
# ### Findings:
#
# Not really an easy way to get jobs/job descs from these:
# - A variety of results (some are Github pages)
# - If you click through --> some link you to third-party job software/webpages etc.
# - You have to parse html which might not be very nice for some pages

# %% [markdown]
# ### Second approach: Try with a SERP API and see what we get
#
# I used https://app.zenserp.com/ because it had a free trial.
#
# This is probably the **best option** for this kind of thing: https://serpapi.com/playground?engine=google_jobs&q=Hypothesis. Didn't have a free trial but the playground is very nice.

# %%
res = [get_zenserp_results(search_text) for search_text in job_pages_df['text']]

# %%
job_pages_df['baseurl'] = job_pages_df['url'].apply(lambda x: str.split(x, '/')[2])

# %%
res_d = []
for i in range(0, len(job_pages_df)):
    # include the result if the url string matches orgs' baseurls from above 
    res_d.append([val for val in res[i]['organic'] if \
     val.get('url') is not None and \
     job_pages_df.iloc[i]['baseurl'] in val.get('url')])

# %%
res_flat = [item for sublist in res_d for item in sublist]

# %%
pd.DataFrame(res_flat)
# Out:
#     position                                              title  \
# 0          1                                  Jobs - Hypothesis
# 1          1                                     Careers - PLOS
# 2          2                     Careers in research - PLOS ONE
# 3          3                              Employment - PLOS ONE
# 4          4                                Get Involved - PLOS
# 5          5                                    Jobs - PLOS ONE
# 6          1                   Opportunities - Creative Commons
# 7          2  New Job Opportunities at Creative Commons - Cr...
# 8          3                   jobs Archives - Creative Commons
# 9          4          opportunities Archives - Creative Commons
# 10         6     Job Opportunity: CEO (2020) - Creative Commons
# 11         7  Creative Commons Internship Opportunities - Cr...
# 12         8  Job Opportunity: Director of Finance - Creativ...
# 13         9  Frequently Asked Questions (FAQ) – Creative Co...
# 14         1                               Dat Project · GitHub
# 15         2               dat-project · GitHub Topics · GitHub
# 16         3  bbalin12/DAT-project-examples: Example project...
# 17         4  awesome-dat/readme.md at master · datproject ....
# 18         5                                  Dat Rust · GitHub
# 19         6           ducvn256/dat-project: jenkins-x - GitHub
# 20         7  datprotocol/DEPs: Dat Enhancement Proposals .....
# 21         1                              Careers - ContentMine
# 22         2           About Us - ContentMine Open Source Tools
#
#                                                   url  \
# 0                       https://web.hypothes.is/jobs/
# 1                           https://plos.org/careers/
# 2   https://journals.plos.org/plosone/browse/caree...
# 3   https://journals.plos.org/plosone/browse/emplo...
# 4                      https://plos.org/get-involved/
# 5       https://journals.plos.org/plosone/browse/jobs
# 6   https://creativecommons.org/about/team/opportu...
# 7   https://creativecommons.org/2016/03/08/new-job...
# 8               https://creativecommons.org/tag/jobs/
# 9      https://creativecommons.org/tag/opportunities/
# 10  https://creativecommons.org/about/team/opportu...
# 11  https://creativecommons.org/2005/03/07/creativ...
# 12  https://creativecommons.org/about/team/opportu...
# 13  https://certificates.creativecommons.org/about...
# 14                      https://github.com/datproject
# 15              https://github.com/topics/dat-project
# 16   https://github.com/bbalin12/DAT-project-examples
# 17  https://github.com/dat-land/awesome-dat/blob/m...
# 18                           https://github.com/datrs
# 19            https://github.com/ducvn256/dat-project
# 20                https://github.com/datprotocol/DEPs
# 21       http://contentmine.org/get-in-touch/careers/
# 22                   http://contentmine.org/about-us/
#
#                                           destination  \
# 0                              web.hypothes.is › jobs
# 1                                  plos.org › careers
# 2   journals.plos.org › plosone › browse › careers...
# 3   journals.plos.org › plosone › browse › employment
# 4                             plos.org › get-involved
# 5         journals.plos.org › plosone › browse › jobs
# 6             creativecommons.org › What We Do › Team
# 7               creativecommons.org › Blog › About CC
# 8                          creativecommons.org › Blog
# 9                          creativecommons.org › Blog
# 10  creativecommons.org › What We Do › Team › Oppo...
# 11                creativecommons.org › Blog › Weblog
# 12  creativecommons.org › What We Do › Team › Oppo...
# 13     certificates.creativecommons.org › about › faq
# 14                            github.com › datproject
# 15                  github.com › topics › dat-project
# 16       github.com › bbalin12 › DAT-project-examples
# 17  github.com › dat-land › awesome-dat › blob › m...
# 18                                 github.com › datrs
# 19                github.com › ducvn256 › dat-project
# 20                    github.com › datprotocol › DEPs
# 21           contentmine.org › get-in-touch › careers
# 22                         contentmine.org › about-us
#
#                                           description  isAmp  \
# 0   We believe the impact of this pervasive conver...  False
# 1   PLOS people have revolutionized science publis...  False
# 2   Get an email alert for Careers in research; Ge...  False
# 3   Employment. Related content. Labor economics ·...  False
# 4   ... your CV can help demonstrate your current ...  False
# 5   Job postings in the substance use disorder tre...  False
# 6   If you are interested in applying, please emai...  False
# 7   Mar 8, 2016 - New Job Opportunities at Creativ...  False
# 8   New job at CC: Director of development. Work f...  False
# 9   Job opportunity: Chief Technology Officer at C...  False
# 10  must operate effectively in multiple time zone...  False
# 11  Mar 7, 2005 - Creative Commons is currently ac...  False
# 12  Job Opportunity: Director of Finance. The Dire...  False
# 13  If you receive less than 90% on any assessment...  False
# 14  A distributed data community. Dat is a nonprof...  False
# 15  GitHub is where people build software. More th...  False
# 16  Example projects from General Assembly Data Sc...  False
# 17  Community curated resources for Dat Project. C...  False
# 18  GitHub is home to over 40 million developers w...  False
# 19  Jul 7, 2019 - GitHub is home to over 40 millio...  False
# 20  Contains all specs for the Dat protocol, inclu...  False
# 21  Responsibilities. Developing graphical client-...  False
# 22  ... find facts hidden in information and suppo...  False
#
#                                             sitelinks
# 0                                                 NaN
# 1   [{'title': 'PLOS ONE: Careers', 'description':...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  [{'title': 'Dat', 'description': '... sharing ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN

# %% [markdown]
# ### Findings:
# This is nicer.
# - You can definitely get a clean list of jobs this way if you wanted to
# - At the very least a title and a link to the listing.
# - If you do use this, I'd recommend going with SerpAPI.com since it allows you to filter by the engine (google_jobs) unlike zenserp.
